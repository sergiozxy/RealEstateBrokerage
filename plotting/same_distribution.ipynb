# %% [markdown]
# # Distribution between brokerages and the attributes
#
# To find out if the brokerages follows a same trend we can use this figure

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import pandas as pd
from scipy import stats
import seaborn as sns

# %%
data = pd.read_stata('../template.dta')

# %%
sns.set_style("whitegrid")  # Sets a background with grid
# Calculate y as the difference between broker_410 and beke_410
y = data['broker_410'] - data['beke_410']

# Fit a polynomial of degree 3 to beke_410 vs y
coefficients = np.polyfit(data['beke_410'], y, 3)
polynomial = np.poly1d(coefficients)

# Generate x values for plotting the polynomial fit
x_poly = np.linspace(min(data['beke_410']), max(data['beke_410']), 100)
y_poly = polynomial(x_poly)

plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size
ax = sns.scatterplot(x=data['beke_410'], y=y, color='blue', s=50, edgecolor='none')

# Add polynomial curve to the scatter plot
plt.plot(x_poly, y_poly, color='red')  # Red for better visibility

plt.xlabel('Number of Beke\'s Stores')
plt.ylabel('Number of Other Brokerages\'s Stores')
# plt.title('Scatter Plot with Cubic Polynomial Fit')
plt.savefig('../figures/scatter_plot_with_two_brokerages.pdf', dpi=300)
# plt.show()
