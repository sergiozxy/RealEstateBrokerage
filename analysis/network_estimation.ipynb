# %%
import networkx as nx
import pybind11
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import geopandas as gpd
import shapely 
import os
import marimo
import sys
import re
os.chdir(r'E:\umich\RealEstateBrokerage-main')

# %%
data = pd.read_stata('individual.dta')

# %%
map_data = data[(data['city'] == 'beijing') & (data['year'] == 2016)]
df = pd.read_csv("classifying brokerages/processed/16_北京市.csv")

# %%
# Out:
#                      name                               type        gpsx  \
# 0     21世纪不动产(SOHO·尚都南北塔)          公司企业;公司;公司|生活服务;中介机构;中介机构  116.446849
# 1                      链家  生活服务;中介机构;中介机构|购物服务;购物相关场所;购物相关场所  116.456334
# 2                      链家  生活服务;中介机构;中介机构|购物服务;购物相关场所;购物相关场所  116.461314
# 3                      链家  生活服务;中介机构;中介机构|购物服务;购物相关场所;购物相关场所  116.461018
# 4                      链家  生活服务;中介机构;中介机构|购物服务;购物相关场所;购物相关场所  116.449045
# ...                   ...                                ...         ...
# 1074               顺置家房地产                     生活服务;中介机构;中介机构  117.097768
# 1075                   链家                     生活服务;中介机构;中介机构  116.657717
# 1076                   链家                     生活服务;中介机构;中介机构  116.646835
# 1077                   链家                     生活服务;中介机构;中介机构  116.651547
# 1078                   链家                     生活服务;中介机构;中介机构  116.643597
#
#            gpsy  year Chinese_Name first_two  two  number  label
# 0     39.917717    16          北京市        21   21  2635.0    2.0
# 1     39.875065    16          北京市        链家   链家  7176.0    0.0
# 2     39.927974    16          北京市        链家   链家  7176.0    0.0
# 3     39.926613    16          北京市        链家   链家  7176.0    0.0
# 4     39.966118    16          北京市        链家   链家  7176.0    0.0
# ...         ...   ...          ...       ...  ...     ...    ...
# 1074  40.135235    16          北京市        顺置  NaN     NaN    NaN
# 1075  39.888269    16          北京市        链家   链家  7176.0    0.0
# 1076  39.886847    16          北京市        链家   链家  7176.0    0.0
# 1077  39.900035    16          北京市        链家   链家  7176.0    0.0
# 1078  39.905179    16          北京市        链家   链家  7176.0    0.0
#
# [1079 rows x 10 columns]
